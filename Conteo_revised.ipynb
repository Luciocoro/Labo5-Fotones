# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyvisa as visa
import time
from scipy.signal import find_peaks
from osci import TDS1002B
import os
from os import listdir
from os.path import isfile, join
from time import perf_counter

# %% [markdown]
# <'P'> = NHNU/T

# %%
rm=visa.ResourceManager()

rm.list_resources()
# Out:
# ('USB0::0x0699::0x0363::C065087::INSTR',
#  'ASRL1::INSTR',
#  'ASRL2::INSTR',
#  'ASRL3::INSTR',
#  'ASRL10::INSTR')

# %%
osci = TDS1002B('USB0::0x0699::0x0363::C065087::INSTR')

# %%
data, tiempo = osci.read_data(channel = 1) #mide, efectivamente

# %% [markdown]
# MEDICIONES

# %%
#MEDIMOS

nro_mediciones = 10
iteracion = 6
tiempo_integracion = 10 #


Carpeta_Ruido = "Ruido de fondo"
Carpeta_Laser = "Mediciones con laser"
Carpeta_Resistencia = 'Mediciones con Resistencia'

newpath = f'Clase 01-11/{Carpeta_Resistencia}/iteración {iteracion}'
os.makedirs(newpath)

PG = 40 #Polarizador Grande
PC = 0  #Polarizador Chico


for i in range(nro_mediciones):
    t0 = time.perf_counter()
    print(f'Medición nro {i}')
    d,t = osci.read_data(channel = 1)
    # t2,d2 = osci.read_data(channel = 2)
    t1 = time.perf_counter()

    datos = {
    'Mediciónes' : d,
    'Tiempo' : t,
    'Tiempo de integración [ms]' : tiempo_integracion,
    "Polarizacion grande" : PG,
    "Polarizacion chica" : PC,
    "Resistencia" : 50
    }

    df = pd.DataFrame.from_dict(datos)
    df.to_csv(f"{newpath}/Medición nro {i}.csv", encoding = "utf-8")
    
    time.sleep(0.01)
    tf = time.perf_counter()
    print(f'Tiempo de medición: {t1 -t0}s\nTiempo de guardado: {tf-t1}s\ntiempo total de medicion: {tf-t0}s')

# %% [markdown]
# Batch plot

# %%
#PLOTEAMOS
plt.style.use('./figuras_lucio.mplstyle')

Carpeta_Ruido = "Ruido de fondo"
Carpeta_Laser = "Mediciones con laser"
Carpeta_Resistencia = 'Mediciones con Resistencia'
iteracion = 0

path = f'Clase 01-11/{Carpeta_Laser}/Iteración {iteracion}'
onlyfiles = [file for file in listdir(path) if isfile(join(path, file))]

fig, ax = plt.subplots()

batch_nr = 4
for file in onlyfiles:
    df = pd.read_csv(join(path, file))
    t = df['Datos'].values
    d = df["Tiempo"].values
    d_mean = np.mean(d)
    d_std = np.std(d)

    ax.plot(t,d);


xlabels = np.linspace(t[0],t[-1],10,endpoint = True)
ax.set_xticks(xlabels)
ax.set_xticklabels([f'{number:.3f}' for number in xlabels]);

ax.set_ylabel('Voltaje [$\mu$V]')
ax.set_xlabel('Ventana de integración [s]')
ax.set_title(f"Tiempo de integracion {df['Tiempo de integración [ms]'].values[0]}ms")

ax.hlines(d_mean - 4*d_std,t[0],t[-1],color = 'black');
ax.hlines(d_mean,t[0],t[-1],color = 'black');


# fig.savefig(f'Clase 01-11/{Carpeta_Laser}/Figuras/Iteración {iteracion}.png',dpi = 800)


#Cualquier electron genera la avanlancha, no son nescesariamente osn Fotonoes

# %%
#PLOTEAMOS
fig, ax = plt.subplots(figsize = (12,7))
Carpeta_Ruido = "Ruido de fondo"
Carpeta_Laser = "Mediciones con laser"
batch_nr = 4
for i in range(50):
    filename = rf'C:/Users/publico/Desktop/G6L5V/Clase 01-11/{Carpeta_Laser}/iteración {batch_nr} Medición nro {i}.csv'
    df = pd.read_csv(filename)
    t = df['Datos'].values
    d = df["Tiempo"].values
    d_mean = np.mean(d)
    d_std = np.std(d)

    ax.plot(t,d)
    
t_i = df['Tiempo de integración [ms]'].values[0]
pg = df["Polarizacion grande"] = pd.Series(PG,index = [0])
pc = df["Polarizacion chica"] = pd.Series(PC,index = [0])  

ax.grid()
ax.set_xlim(t[0],t[-1])
xlabels = np.linspace(t[0],t[-1],10,endpoint = True)
ax.set_xticks(xlabels)
ax.set_xticklabels([f'{number:.3f}' for number in xlabels]);

ax.set_ylabel('Voltaje [mV]',fontsize = 18)
ax.set_xlabel('Ventana de integración [s]',fontsize = 18)
ax.set_title(f"Tiempo de integracion {df['Tiempo de integración [ms]'].values[0]}ms")

ax.hlines(d_mean - 4*d_std,t[0],t[-1])
ax.hlines(d_mean,t[0],t[-1])

# %% [markdown]
# Single plot

# %%
fig, ax = plt.subplots(figsize = (12,7))

filename1 = rf'C:/Users/publico/Desktop/G6L5V/Clase 01-11/Ruido de fondo/Medición nro {0}.csv'
filename2 = rf'C:/Users/publico/Desktop/G6L5V/Clase 01-11/Ruido de fondo/Medición nro {49}.csv'


df1 = pd.read_csv(filename1)
df2 = pd.read_csv(filename2)


t1 = df1['Datos']  
t2 = df2['Datos']

d1 = df1["Tiempo"]
d2 = df2['Tiempo']

ax.plot(t1,d1)
ax.plot(t2,d2)

# %%
#MEDIMOS SIN LASE
nro_mediciones = 100
iteracion = 4
tiempo_integracion = 1

PG = -40 #Polarizador Grande
PC = 0  #Polarizador Chico

data = []
tiempo = []

for i in range(nro_mediciones):
    t0 = time.time()
    print(f'Medición nro {i}')
    df = pd.DataFrame()
    t,d = osci.read_data(channel = 1)
    df['Datos'] = t 
    df["Tiempo"] = d #Tension en R2
    df['Tiempo de integración [ms]'] = pd.Series(tiempo_integracion,index = [0])
    df["Polarizacion grande"] = pd.Series(PG,index = [0])
    df["Polarizacion chica"] = pd.Series(PC,index = [0])
    df.to_csv(f"C:/Users/publico/Desktop/G6L5V/Clase 01-11/Ruido de fondo/iteración {iteracion} Medición nro {i}.csv", encoding = "utf-8")
    time.sleep(0.05)
    tf = time.time()
    print(f'Tiempo de medición: {tf -t0}s')
# Out:
# Medición nro 0
# Tiempo de medición: 1.1563491821289062s
# Medición nro 1
# Tiempo de medición: 1.2885441780090332s
# Medición nro 2
# Tiempo de medición: 1.1580076217651367s
# Medición nro 3
# Tiempo de medición: 1.2904164791107178s
# Medición nro 4
# Tiempo de medición: 1.155785322189331s
# Medición nro 5
# Tiempo de medición: 1.339533805847168s
# Medición nro 6
# Tiempo de medición: 1.158790111541748s
# Medición nro 7
# Tiempo de medición: 1.3111224174499512s
# Medición nro 8
# Tiempo de medición: 1.1591522693634033s
# Medición nro 9
# Tiempo de medición: 1.2867088317871094s
# Medición nro 10
# Tiempo de medición: 1.154050588607788s
# Medición nro 11
# Tiempo de medición: 1.294651746749878s
# Medición nro 12
# Tiempo de medición: 1.1564476490020752s
# Medición nro 13
# Tiempo de medición: 1.2856128215789795s
# Medición nro 14
# Tiempo de medición: 1.1557979583740234s
# Medición nro 15
# Tiempo de medición: 1.2914013862609863s
# Medición nro 16
# Tiempo de medición: 1.1965134143829346s
# Medición nro 17
# Tiempo de medición: 1.2459540367126465s
# Medición nro 18
# Tiempo de medición: 1.1564006805419922s
# Medición nro 19
# Tiempo de medición: 1.286531686782837s
# Medición nro 20
# Tiempo de medición: 1.1550865173339844s
# Medición nro 21
# Tiempo de medición: 1.2881288528442383s
# Medición nro 22
# Tiempo de medición: 1.1559967994689941s
# Medición nro 23
# Tiempo de medición: 1.2923200130462646s
# Medición nro 24
# Tiempo de medición: 1.1593246459960938s
# Medición nro 25
# Tiempo de medición: 1.291637897491455s
# Medición nro 26
# Tiempo de medición: 1.2129325866699219s
# Medición nro 27
# Tiempo de medición: 1.2466840744018555s
# Medición nro 28
# Tiempo de medición: 1.2078351974487305s
# Medición nro 29
# Tiempo de medición: 1.252607822418213s
# Medición nro 30
# Tiempo de medición: 1.1593031883239746s
# Medición nro 31
# Tiempo de medición: 1.8407156467437744s
# Medición nro 32
# Tiempo de medición: 1.158463954925537s
# Medición nro 33
# Tiempo de medición: 1.298553705215454s
# Medición nro 34
# Tiempo de medición: 1.1977932453155518s
# Medición nro 35
# Tiempo de medición: 1.2529451847076416s
# Medición nro 36
# Tiempo de medición: 1.155179500579834s
# Medición nro 37
# Tiempo de medición: 1.292548656463623s
# Medición nro 38
# Tiempo de medición: 1.1952996253967285s
# Medición nro 39
# Tiempo de medición: 1.25119948387146s
# Medición nro 40
# Tiempo de medición: 1.292034387588501s
# Medición nro 41
# Tiempo de medición: 1.1584901809692383s
# Medición nro 42
# Tiempo de medición: 1.2873127460479736s
# Medición nro 43
# Tiempo de medición: 1.1604440212249756s
# Medición nro 44
# Tiempo de medición: 1.292123794555664s
# Medición nro 45
# Tiempo de medición: 1.2117092609405518s
# Medición nro 46
# Tiempo de medición: 1.2323787212371826s
# Medición nro 47
# Tiempo de medición: 1.1583476066589355s
# Medición nro 48
# Tiempo de medición: 1.2963807582855225s
# Medición nro 49
# Tiempo de medición: 1.1594550609588623s
# Medición nro 50
# Tiempo de medición: 1.288593053817749s
# Medición nro 51
# Tiempo de medición: 1.1551496982574463s
# Medición nro 52
# Tiempo de medición: 1.2970919609069824s
# Medición nro 53
# Tiempo de medición: 1.2110509872436523s
# Medición nro 54
# Tiempo de medición: 1.2882256507873535s
# Medición nro 55
# Tiempo de medición: 1.1684048175811768s
# Medición nro 56
# Tiempo de medición: 1.2934894561767578s
# Medición nro 57
# Tiempo de medición: 1.2830216884613037s
# Medición nro 58
# Tiempo de medición: 1.1619861125946045s
# Medición nro 59
# Tiempo de medición: 1.2922065258026123s
# Medición nro 60
# Tiempo de medición: 1.159287929534912s
# Medición nro 61
# Tiempo de medición: 1.3096201419830322s
# Medición nro 62
# Tiempo de medición: 1.1605303287506104s
# Medición nro 63
# Tiempo de medición: 1.2929646968841553s
# Medición nro 64
# Tiempo de medición: 1.1577608585357666s
# Medición nro 65
# Tiempo de medición: 1.2853350639343262s
# Medición nro 66
# Tiempo de medición: 1.1593313217163086s
# Medición nro 67
# Tiempo de medición: 1.2852444648742676s
# Medición nro 68
# Tiempo de medición: 1.3484444618225098s
# Medición nro 69
# Tiempo de medición: 1.1968357563018799s
# Medición nro 70
# Tiempo de medición: 1.2466719150543213s
# Medición nro 71
# Tiempo de medición: 1.1550042629241943s
# Medición nro 72
# Tiempo de medición: 1.2903387546539307s
# Medición nro 73
# Tiempo de medición: 1.2904212474822998s
# Medición nro 74
# Tiempo de medición: 1.1968176364898682s
# Medición nro 75
# Tiempo de medición: 1.2549090385437012s
# Medición nro 76
# Tiempo de medición: 1.1529145240783691s
# Medición nro 77
# Tiempo de medición: 1.293168306350708s
# Medición nro 78
# Tiempo de medición: 1.1958749294281006s
# Medición nro 79
# Tiempo de medición: 1.2469618320465088s
# Medición nro 80
# Tiempo de medición: 1.1556706428527832s
# Medición nro 81
# Tiempo de medición: 1.2862532138824463s
# Medición nro 82
# Tiempo de medición: 1.1682074069976807s
# Medición nro 83
# Tiempo de medición: 1.2786204814910889s
# Medición nro 84
# Tiempo de medición: 1.1561896800994873s
# Medición nro 85
# Tiempo de medición: 1.2899169921875s
# Medición nro 86
# Tiempo de medición: 1.1541378498077393s
# Medición nro 87
# Tiempo de medición: 1.2840073108673096s
# Medición nro 88
# Tiempo de medición: 1.159616231918335s
# Medición nro 89
# Tiempo de medición: 1.2940192222595215s
# Medición nro 90
# Tiempo de medición: 1.1974692344665527s
# Medición nro 91
# Tiempo de medición: 1.252788782119751s
# Medición nro 92
# Tiempo de medición: 1.3472747802734375s
# Medición nro 93
# Tiempo de medición: 1.1588234901428223s
# Medición nro 94
# Tiempo de medición: 1.2924010753631592s
# Medición nro 95
# Tiempo de medición: 1.193746566772461s
# Medición nro 96
# Tiempo de medición: 1.2538654804229736s
# Medición nro 97
# Tiempo de medición: 1.2914211750030518s
# Medición nro 98
# Tiempo de medición: 1.1939518451690674s
# Medición nro 99
# Tiempo de medición: 1.2509644031524658s

# %%
#PLOTEAMOS
fig, ax = plt.subplots(2,1,figsize = (12,7),sharex=True)
batch_nr = 1
for i in range(20):
    filename = rf'C:/Users/publico/Desktop/G6L5V/Clase 01-11/{Carpeta_Resistencia}/iteración {batch_nr} Medición nro {i}.csv'
    df = pd.read_csv(filename)
    t = df['Datos'].values
    d = df["Tiempo"].values
    t2 = df['Datos Ch2'].values
    d2 = df["Tiempo Ch2"].values
    d_mean = np.mean(d)
    d_std = np.std(d)

    ax[0].plot(t,d)
    ax[1].plot(t2,d2)
    
t_i = df['Tiempo de integración [ms]'].values[0]
pg = df["Polarizacion grande"] = pd.Series(PG,index = [0])
pc = df["Polarizacion chica"] = pd.Series(PC,index = [0])

ax[0].grid()
ax[1].grid()
ax[0].set_xlim(t[0],t[-1])
xlabels = np.linspace(t[0],t[-1],10,endpoint = True)
ax[0].set_xticks(xlabels)
ax[0].set_xticklabels([f'{number:.3f}' for number in xlabels]);

ax[0].set_ylabel('Voltaje [mV]',fontsize = 18)
ax[0].set_xlabel('Ventana de integración [s]',fontsize = 18)
ax[0].set_title(f"Tiempo de integracion {df['Tiempo de integración [ms]'].values[0]}ms")

ax[0].hlines(d_mean - 4*d_std,t[0],t[-1])
ax[0].hlines(d_mean,t[0],t[-1])
fig.savefig('Mediciones',dpi = 800)
#Cualquier electron genera la avanlancha, no son nescesariamente osn Fotonoes
